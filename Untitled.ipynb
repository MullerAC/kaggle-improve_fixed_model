# %%
import pandas as pd
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split

# %%
def split(df):

    train, test = train_test_split(df)

    return train, test

# %%
def rsme(y_true, y_pred):
    
    rmse = mean_squared_error(y_true, y_pred, squared=False)
    
    return rmse

# %%
def predict(train, y_train, test):
    
    rf = RandomForestRegressor(
           n_estimators=1000,
           max_depth=7,
           n_jobs=-1,
           random_state=42)
    rf.fit(train, y_train)
    
    y_hat = rf.predict(test)
    
    return y_hat

# %%
def evaluate(train, test):
    
    y_train = train.pop('target')
    x_train = train.copy()
    
    y_test = test.pop('target')
    x_test = test.copy()
    
    y_pred = predict(x_train, y_train, x_test)

    rmse = rsme(y_test, y_pred)
    
    return rmse

# %%
df = pd.read_csv('files/sample_submission.csv', index_col='id')
df
# Out:
#       target    O2_1    O2_2   O2_3   O2_4   O2_5    O2_6   O2_7  NH4_1  \
# id
# 0       8.59   7.500   9.000  9.545  9.265  8.110   8.430  7.150  0.180
# 1       9.10  13.533  40.900  8.770  9.265  6.015  10.070  7.150  1.107
# 2       8.21   3.710   5.420  8.770  9.265  4.550  10.070  7.150  0.020
# 3       8.39   8.700   8.100  9.500  9.200  5.200   8.670  6.670  0.280
# 4       8.07   8.050   8.650  7.960  9.265  3.290  10.070  7.150  0.360
# ...      ...     ...     ...    ...    ...    ...     ...    ...    ...
# 3495    8.08   6.250   8.300  7.795  9.265  5.690   8.555  6.335  0.565
# 3496    8.09   6.630   6.630  8.370  7.600  0.636   8.430  7.150  1.300
# 3497    9.95   8.367   8.433  8.770  6.170  5.800  10.400  7.200  0.430
# 3498    9.52  10.000   6.630  9.545  9.265  3.290   8.980  2.310  0.300
# 3499    8.51   8.500   8.100  9.545  9.265  8.110   9.805  7.150  0.215
#
#       NH4_2  ...   NO3_5  NO3_6  NO3_7  BOD5_1  BOD5_2  BOD5_3  BOD5_4  \
# id           ...
# 0     0.200  ...   4.950  1.730  1.800   4.800   3.150  10.665  10.465
# 1     1.027  ...  20.050  9.530  7.695   4.550   6.950   2.040   5.200
# 2     0.020  ...   4.580  3.025  3.960   4.935   4.950   4.725   6.075
# 3     0.270  ...   8.450  2.070  1.730   6.300   4.700   3.500   6.200
# 4     0.435  ...   2.020  1.730  0.760   4.800   4.970   3.950   2.800
# ...     ...  ...     ...    ...    ...     ...     ...     ...     ...
# 3495  0.565  ...  14.575  0.636  1.640   4.235   4.100   2.800   3.950
# 3496  2.200  ...   4.580  1.730  1.800   4.900   3.150   2.040   6.075
# 3497  0.400  ...  20.050  1.440  1.800   4.867   4.833   4.725   4.950
# 3498  0.200  ...  20.050  9.530  7.695  10.700   5.400   4.725   3.300
# 3499  0.200  ...   3.070  1.730  1.800   1.720   2.520   2.040   2.040
#
#       BOD5_5  BOD5_6  BOD5_7
# id
# 0     16.645   5.750   10.37
# 1      5.725   2.950    2.23
# 2      6.750   3.500    3.17
# 3      8.670   2.900    7.37
# 4      8.400   3.500    3.90
# ...      ...     ...     ...
# 3495   7.695   3.540    2.50
# 3496   8.415   2.155    2.90
# 3497   8.400   6.625    4.20
# 3498   6.750   6.625    5.00
# 3499   8.415   2.950    2.27
#
# [3500 rows x 36 columns]

# %%
*split(df)
# Out:
#   Cell In[9], line 1
#     *split(df)
#     ^
# SyntaxError: can't use starred expression here

# %%
evaluate(*split(df))
# Out:
# 2.315376806197196
